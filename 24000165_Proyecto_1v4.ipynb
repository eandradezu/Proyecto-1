# %%
import numpy as np
import pandas as pd
proyecto=np.load('proyecto_training_data.npy')
proyecto
# Out:
# array([[2.08500e+05, 7.00000e+00, 8.56000e+02, 8.00000e+00, 2.00300e+03,
#         6.50000e+01],
#        [1.81500e+05, 6.00000e+00, 1.26200e+03, 6.00000e+00, 1.97600e+03,
#         8.00000e+01],
#        [2.23500e+05, 7.00000e+00, 9.20000e+02, 6.00000e+00, 2.00100e+03,
#         6.80000e+01],
#        ...,
#        [2.66500e+05, 7.00000e+00, 1.18800e+03, 9.00000e+00, 1.94100e+03,
#         6.60000e+01],
#        [1.42125e+05, 5.00000e+00, 1.07800e+03, 5.00000e+00, 1.95000e+03,
#         6.80000e+01],
#        [1.47500e+05, 5.00000e+00, 1.25600e+03, 6.00000e+00, 1.96500e+03,
#         7.50000e+01]])

# %%
proyecto.shape
# Out:
# (1460, 6)

# %%
n_train = int(0.8 * proyecto.shape[0])  
train, test = np.split(proyecto, [n_train])

# %%
train.shape
# Out:
# (1168, 6)

# %%
nomcol= ['Sale_Price','OverallQual','area_F1','RoomsAbGr','Y_built','Street']
train_df=pd.DataFrame(train, columns=nomcol)
train_df
# Out:
#       Sale_Price  OverallQual  area_F1  RoomsAbGr  Y_built  Street
# 0       208500.0          7.0    856.0        8.0   2003.0    65.0
# 1       181500.0          6.0   1262.0        6.0   1976.0    80.0
# 2       223500.0          7.0    920.0        6.0   2001.0    68.0
# 3       140000.0          7.0    961.0        7.0   1915.0    60.0
# 4       250000.0          8.0   1145.0        9.0   2000.0    84.0
# ...          ...          ...      ...        ...      ...     ...
# 1163    108959.0          4.0   1258.0        6.0   1969.0    60.0
# 1164    194000.0          5.0   1432.0        5.0   1978.0     NaN
# 1165    233170.0          7.0   1502.0        7.0   2009.0    79.0
# 1166    245350.0          8.0   1694.0        7.0   2008.0    64.0
# 1167    173000.0          6.0    959.0        7.0   2000.0    58.0
#
# [1168 rows x 6 columns]

# %%
test.shape
# Out:
# (292, 6)

# %%
nomcol= ['Sale_Price','OverallQual','area_F1','RoomsAbGr','Y_built','Street']
test_df=pd.DataFrame(test, columns=nomcol)
test_df
# Out:
#      Sale_Price  OverallQual  area_F1  RoomsAbGr  Y_built  Street
# 0      235000.0          6.0   1236.0        7.0   1935.0   120.0
# 1      625000.0         10.0   1831.0       10.0   1995.0   118.0
# 2      171000.0          6.0   1118.0        6.0   1977.0    76.0
# 3      163000.0          6.0   1261.0        6.0   1958.0    76.0
# 4      171900.0          7.0    625.0        5.0   2006.0    35.0
# ..          ...          ...      ...        ...      ...     ...
# 287    175000.0          6.0    953.0        7.0   1999.0    62.0
# 288    210000.0          6.0   2073.0        7.0   1978.0    85.0
# 289    266500.0          7.0   1188.0        9.0   1941.0    66.0
# 290    142125.0          5.0   1078.0        5.0   1950.0    68.0
# 291    147500.0          5.0   1256.0        6.0   1965.0    75.0
#
# [292 rows x 6 columns]

# %%
train_data=train_df.describe()
train_media= train_data.loc['mean']
train_min= train_data.loc['min']
train_max= train_data.loc['max']
train_rango= train_df.max() - train_df.min()
train_desv_est= train_data.loc['std']
print('Media')
print (train_media)
print ('-------------------------------------------------------')
print('Mínimo')
print(train_min)
print ('-------------------------------------------------------')
print('Máximo')
print(train_max)
print ('-------------------------------------------------------')
print('Rango, peak to peak')
print(train_rango)
print ('-------------------------------------------------------')
print('Desviación estándar')
print(train_desv_est)
# Out:
# Media
# Sale_Price     180590.277397
# OverallQual         6.101027
# area_F1          1156.323630
# RoomsAbGr           6.485445
# Y_built          1971.451199
# Street             69.946985
# Name: mean, dtype: float64
# -------------------------------------------------------
# Mínimo
# Sale_Price     34900.0
# OverallQual        1.0
# area_F1          334.0
# RoomsAbGr          2.0
# Y_built         1875.0
# Street            21.0
# Name: min, dtype: float64
# -------------------------------------------------------
# Máximo
# Sale_Price     755000.0
# OverallQual        10.0
# area_F1          3228.0
# RoomsAbGr          14.0
# Y_built          2010.0
# Street            313.0
# Name: max, dtype: float64
# -------------------------------------------------------
# Rango, peak to peak
# Sale_Price     720100.0
# OverallQual         9.0
# area_F1          2894.0
# RoomsAbGr          12.0
# Y_built           135.0
# Street            292.0
# dtype: float64
# -------------------------------------------------------
# Desviación estándar
# Sale_Price     78815.697902
# OverallQual        1.378025
# area_F1          373.780374
# RoomsAbGr          1.609141
# Y_built           29.951707
# Street            23.478161
# Name: std, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for column in train_df.columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(train_df[column], kde=True)
# Out:
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\erick\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
OverallQual_corr= train_df['OverallQual'].corr(train_df['Sale_Price'])
plt.figure(figsize=(8, 6))
plt.scatter(train_df['OverallQual'], train_df['Sale_Price'])
plt.title(f'Overall Quality vs Sale Price, Coeficiente de correlación: {OverallQual_corr:4f}')
plt.show()

# %%
area_F1_corr= train_df['area_F1'].corr(train_df['Sale_Price'])
plt.figure(figsize=(8, 6))
plt.scatter(train_df['area_F1'], train_df['Sale_Price'])
plt.title(f'First Floor area in squared feet vs Sale Price, Coeficiente de correlación: {area_F1_corr:4f}')
plt.show()

# %%
RoomsAbGr_corr= train_df['RoomsAbGr'].corr(train_df['Sale_Price'])
plt.figure(figsize=(8, 6))
plt.scatter(train_df['RoomsAbGr'], train_df['Sale_Price'])
plt.title(f'Total Rooms Above Grade vs Sale Price, Coeficiente de correlación: {RoomsAbGr_corr:4f}')
plt.show()

# %%
Y_built_corr= train_df['Y_built'].corr(train_df['Sale_Price'])
plt.figure(figsize=(8, 6))
plt.scatter(train_df['Y_built'], train_df['Sale_Price'])
plt.title(f'Year Built vs Sale Price, Coeficiente de correlación: {Y_built_corr:4f}')
plt.show()

# %%
Street_corr= train_df['Street'].corr(train_df['Sale_Price'])
plt.figure(figsize=(8, 6))
plt.scatter(train_df['Street'], train_df['Sale_Price'])
plt.title(f'Street connected to property vs Sale Price, Coeficiente de correlación: {Street_corr:4f}')
plt.show()

# %% [markdown]
# ### Basado en las gráficas de dispersión y sus coeficientes de correlación, se escogen las variables
# ## Overall Quality y First Floor area in squared feet

# %%
#array de variable independiente 1 (Overall Quality) y 1
x1=np.array(train_df['OverallQual'])
x1_1=np.full(len(x1),1)
x1_array=np.column_stack((x1_1,x1))

#array de B0 y B1
b0=np.full(len(x1),float(1))
b1=np.full(len(x1),float(1))
b_array=np.column_stack((b0,b1))

#array de y estimado, producto punto de ambos arrays X-1 y B0-B1
est_y1=np.sum(x1_array* b_array,axis=1)

#array de variable independiente a calcular (Sale Price)
y=np.array(train_df['Sale_Price'])

#calculo de error total
dif1=(y-est_y1)**2
err1=np.mean(np.sqrt(dif1))

#calculo de error por B0 y B1
estdos_y1=np.column_stack((est_y1,est_y1))
errb1=np.mean(estdos_y1*x1_array, axis=0)

#ajuste a B0 y B1 con alfa=0.5
alfa=0.05
b_ajustado=b_array-(alfa*errb1)
b_ajustado

#guardar iteraciones en un diciionario
itx1={}

for i in range(1,101)
    itx1[]=(err1,b_array[0],)

# graficar número de iteracion y su error
iteracion1=list(prueba.keys())
error1=[valor[0] for valor in prueba.values()]
plt.scatter(iteracion, error)

# graficar línea de tendencia cada iteración
plt.plot(x1, est_y1)

# %%
import numpy as np

def regresion_lineal (x,y,epochs, imprimir_error_cada, learning_rate):
    x1=np.array(x)
    x1_1=np.full(len(x1),1)
    x1_array=np.column_stack((x1_1,x1))

    b0=np.full(len(x1),float(180590))
    b1=np.full(len(x1),float(0))
    b_array=np.column_stack((b0,b1))

    itx1={}

    for i in range(1,epochs):
        est_y1=np.sum(x1_array* b_array,axis=1)
        dif1=(np.array(y)-est_y1)**2
        err1=np.mean(np.sqrt(dif1))
        if i % imprimir_error_cada == 0:
            print('Iteración ',i, ', Error promedio: ',err1)
        if i % 50 == 0:
            plt.plot(x1, est_y1)
            plt.show()
        itx1[i]=(err1,b_array[0])
        estdos_y1=np.column_stack((est_y1,est_y1))
        errb1=np.mean(estdos_y1*x1_array, axis=0)
        
        b_array=b_array-(learning_rate*errb1)

    iteracion=list(itx1.keys())
    error=[valor[0] for valor in itx1.values()]
    plt.scatter(iteracion, error)

# %%
regresion_lineal(train_df['OverallQual'],train_df['Sale_Price'],301,5,0.05)
# Out:
# Iteración  5 , Error promedio:  57439.116494312155
# Iteración  10 , Error promedio:  350617.52837005205
# Iteración  15 , Error promedio:  57779.430617266364
# Iteración  20 , Error promedio:  357342.6784204319
# Iteración  25 , Error promedio:  58702.8639860799
# Iteración  30 , Error promedio:  364305.1397329324
# Iteración  35 , Error promedio:  60173.97184628927
# Iteración  40 , Error promedio:  371513.9054566291
# Iteración  45 , Error promedio:  62215.08969716873
# Iteración  50 , Error promedio:  378978.2943990841
# Iteración  55 , Error promedio:  64829.6509160329
# Iteración  60 , Error promedio:  386713.7461271243
# Iteración  65 , Error promedio:  68230.84653575865
# Iteración  70 , Error promedio:  394727.5669809227
# Iteración  75 , Error promedio:  72313.10578375988
# Iteración  80 , Error promedio:  403027.11691672646
# Iteración  85 , Error promedio:  77122.59830720937
# Iteración  90 , Error promedio:  411623.1518960251
# Iteración  95 , Error promedio:  82646.55681398524
# Iteración  100 , Error promedio:  420526.81901425554
# Iteración  105 , Error promedio:  88813.32490747893
# Iteración  110 , Error promedio:  429749.6710397896
# Iteración  115 , Error promedio:  95654.25884011855
# Iteración  120 , Error promedio:  439303.6814857753
# Iteración  125 , Error promedio:  103228.25064842153
# Iteración  130 , Error promedio:  449205.0048790333
# Iteración  135 , Error promedio:  111477.82115136043
# Iteración  140 , Error promedio:  459466.6127271529
# Iteración  145 , Error promedio:  120313.8839254239
# Iteración  150 , Error promedio:  470097.9982610589
# Iteración  155 , Error promedio:  129834.75607235375
# Iteración  160 , Error promedio:  481112.98681866407
# Iteración  165 , Error promedio:  139962.0085241232
# Iteración  170 , Error promedio:  492525.90865575126
# Iteración  175 , Error promedio:  150666.41231909677
# Iteración  180 , Error promedio:  504356.4159087028
# Iteración  185 , Error promedio:  161919.12860980022
# Iteración  190 , Error promedio:  516618.0516889189
# Iteración  195 , Error promedio:  173745.26212685974
# Iteración  200 , Error promedio:  529323.8817058326
# Iteración  205 , Error promedio:  186123.9456943794
# Iteración  210 , Error promedio:  542490.4574142188
# Iteración  215 , Error promedio:  199036.9950237518
# Iteración  220 , Error promedio:  556134.9360452163
# Iteración  225 , Error promedio:  212496.61420206015
# Iteración  230 , Error promedio:  570275.1030314504
# Iteración  235 , Error promedio:  226474.2220140791
# Iteración  240 , Error promedio:  584929.395256304
# Iteración  245 , Error promedio:  240996.4677845413
# Iteración  250 , Error promedio:  600116.9251577333
# Iteración  255 , Error promedio:  256096.97604303996
# Iteración  260 , Error promedio:  615857.5057180894
# Iteración  265 , Error promedio:  271828.97783750715
# Iteración  270 , Error promedio:  632171.6763731298
# Iteración  275 , Error promedio:  288180.73884430074
# Iteración  280 , Error promedio:  649080.729873459
# Iteración  285 , Error promedio:  305141.57825867966
# Iteración  290 , Error promedio:  666606.740134065
# Iteración  295 , Error promedio:  322743.9202719828
# Iteración  300 , Error promedio:  684772.5911081951

# %%
itx1

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x_mod = np.array(train_df['OverallQual']).reshape(-1,1)
y_mod = np.array(train_df['Sale_Price'])      

modelo = LinearRegression()
modelo.fit(X_mod, y_mod)
# Out:
# LinearRegression()

# %%
sk_estimado=modelo.predict(np.array(test_df['OverallQual']).reshape(-1,1))
plt.scatter(test_df['OverallQual'], sk_estimado)

# %%
modelo.intercept_
# Out:
# -96469.57131874

# %%
modelo.coef_[0]
# Out:
# 45411.998779159185
